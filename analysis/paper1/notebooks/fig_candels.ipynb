# %% [markdown]
# # Three CANDELS galaxies in detail
#
# Paper label `fig:candels`, file `figures/fig05_candels_galaxies.pdf`.
#
# One galaxy per colour class: photometry with the posterior-predictive band, the star formation history, and a corner of the key parameters, under all six configurations.
#
# **Script:** `analysis/paper1/fig05_candels_galaxies.py`, run as a module from the checkout root.
# **Requires:** The production grid's cells in results/fits, and tengri, because the posterior predictive is recomputed from the model.
#
# Set `PAPER1_CHECKOUT` to render from another checkout, and `PAPER_FIGURES_DIR` to copy the PDF into the paper.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd()))  # this notebook's directory, which holds _driver.py
import _driver as drv

P = drv.paths(drv.find_checkout())
drv.provenance(P)

# %%
inputs = drv.check_inputs(P, ["results/fits"])

# %%
log = drv.run_module(P, "paper1.fig05_candels_galaxies")

# %%
drv.show(P, "fig05_candels_galaxies")

# %%
drv.copy_to_paper(P, "fig05_candels_galaxies.pdf")

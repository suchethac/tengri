# %% [markdown]
# # Six configurations against published per-code values
#
# Paper label `fig:code_overlay`, file `figures/fig06_code_overlay.pdf`.
#
# For all twenty galaxies, the stellar mass and star formation rate from each configuration overlaid on the values published by other SED-fitting codes.
#
# **Script:** `analysis/paper1/fig06_code_overlay.py`, run as a module from the checkout root.
# **Requires:** The production grid's cells in results/fits, the published-values table, and tengri.
#
# Set `PAPER1_CHECKOUT` to render from another checkout, and `PAPER_FIGURES_DIR` to copy the PDF into the paper.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd()))  # this notebook's directory, which holds _driver.py
import _driver as drv

P = drv.paths(drv.find_checkout())
drv.provenance(P)

# %%
inputs = drv.check_inputs(P, ["results/fits", "results/art_sedfitting_z1.csv"])

# %%
log = drv.run_module(P, "paper1.fig06_code_overlay")

# %%
drv.show(P, "fig06_code_overlay")

# %%
drv.copy_to_paper(P, "fig06_code_overlay.pdf")

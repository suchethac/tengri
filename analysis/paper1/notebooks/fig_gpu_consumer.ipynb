# %% [markdown]
# # The same measurement on a consumer GPU (Appendix D)
#
# Paper label `fig:gpu_consumer`, file `figures/figD1_gpu_consumer.pdf`.
#
# Forward and gradient cost against batch size on an RTX 3060 against a Ryzen 9 5900X, the card that leaves the launch-latency floor and shows what single precision buys. The same renderer as the datacenter figure, pointed at the consumer measurement file.
#
# **Script:** `analysis/paper1/fig04_gpu_datacenter.py`, run as a module from the checkout root.
# **Requires:** The committed RTX 3060 measurement file; no model is built.
#
# Set `PAPER1_CHECKOUT` to render from another checkout, and `PAPER_FIGURES_DIR` to copy the PDF into the paper.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd()))  # this notebook's directory, which holds _driver.py
import _driver as drv

P = drv.paths(drv.find_checkout())
drv.provenance(P)

# %%
inputs = drv.check_inputs(P, ["results/consumer_gpu_batch.json"])

# %%
log = drv.run_module(
    P,
    "paper1.fig04_gpu_datacenter",
    "--data", "analysis/paper1/results/consumer_gpu_batch.json",
    "--out", "analysis/paper1/figures/figD1_gpu_consumer.pdf",
)

# %%
drv.show(P, "figD1_gpu_consumer")

# %%
drv.copy_to_paper(P, "figD1_gpu_consumer.pdf")

# %% [markdown]
# # Precomputation error per band against redshift (Appendix B)
#
# Paper label `fig:precomp_accuracy`, file `figures/figB1_lut_accuracy.pdf`.
#
# The photometric error of the precomputed lookup table relative to the exact integration, per band, as a function of redshift.
#
# **Script:** `analysis/paper1/fig03_precompute.py`, run as a module from the checkout root.
# **Requires:** The committed accuracy and benchmark measurement files. The script also writes fig03_precompute.pdf, which the paper does not include.
#
# Set `PAPER1_CHECKOUT` to render from another checkout, and `PAPER_FIGURES_DIR` to copy the PDF into the paper.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd()))  # this notebook's directory, which holds _driver.py
import _driver as drv

P = drv.paths(drv.find_checkout())
drv.provenance(P)

# %%
inputs = drv.check_inputs(P, ["results/fig03_precompute_data.json", "results/fig03_bench_forward_2026-08-30.json"])

# %%
log = drv.run_module(P, "paper1.fig03_precompute")

# %%
drv.show(P, "figB1_lut_accuracy")

# %%
drv.copy_to_paper(P, "figB1_lut_accuracy.pdf")

# %% [markdown]
# # Forward and gradient cost against batch size on a datacenter GPU
#
# Paper label `fig:gpu`, file `figures/fig04_gpu_datacenter.pdf`.
#
# Per-galaxy and per-call wall time of one forward-model evaluation and one gradient evaluation as a function of batch size, an NVIDIA H100 against the Xeon on the same node, in single and double precision.
#
# **Script:** `analysis/paper1/fig04_gpu_datacenter.py`, run as a module from the checkout root.
# **Requires:** The committed H100 measurement file; no model is built.
#
# Set `PAPER1_CHECKOUT` to render from another checkout, and `PAPER_FIGURES_DIR` to copy the PDF into the paper.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd()))  # this notebook's directory, which holds _driver.py
import _driver as drv

P = drv.paths(drv.find_checkout())
drv.provenance(P)

# %%
inputs = drv.check_inputs(P, ["results/sherlock_h100_batch.json"])

# %%
log = drv.run_module(P, "paper1.fig04_gpu_datacenter")

# %%
drv.show(P, "fig04_gpu_datacenter")

# %%
drv.copy_to_paper(P, "fig04_gpu_datacenter.pdf")

# %% [markdown]
# # One galaxy through every inference backend
#
# Paper label `fig:backends`, file `figures/fig07_backends.pdf`.
#
# Galaxy 13097 under Configuration II fitted with MAP, Laplace, NUTS, HMC and nested sampling: the posterior each backend returns and its wall-clock budget.
#
# **Script:** `analysis/paper1/fig07_backends.py`, run as a module from the checkout root.
# **Requires:** The committed backend sweep results; the notebook imports JAX but builds no model.
#
# Set `PAPER1_CHECKOUT` to render from another checkout, and `PAPER_FIGURES_DIR` to copy the PDF into the paper.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd()))  # this notebook's directory, which holds _driver.py
import _driver as drv

P = drv.paths(drv.find_checkout())
drv.provenance(P)

# %%
inputs = drv.check_inputs(P, ["results/backend_sweep_pin"])

# %%
log = drv.run_module(P, "paper1.fig07_backends")

# %%
drv.show(P, "fig07_backends")

# %%
drv.copy_to_paper(P, "fig07_backends.pdf")

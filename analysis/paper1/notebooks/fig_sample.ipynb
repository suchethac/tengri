# %% [markdown]
# # The whole demonstration grid in one frame
#
# Paper label `fig:sample`, file `figures/fig09_sample_level.pdf`.
#
# Twenty galaxies under six configurations in the stellar-mass and star-formation-rate plane, with the configuration-to-configuration shifts per galaxy.
#
# **Script:** `analysis/paper1/fig09_sample_level.py`, run as a module from the checkout root.
# **Requires:** The production grid's cells in results/fits. A partial grid renders with a provenance stamp; the canonical grid renders clean with --no-stamp.
#
# Set `PAPER1_CHECKOUT` to render from another checkout, and `PAPER_FIGURES_DIR` to copy the PDF into the paper.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd()))  # this notebook's directory, which holds _driver.py
import _driver as drv

P = drv.paths(drv.find_checkout())
drv.provenance(P)

# %%
inputs = drv.check_inputs(P, ["results/fits"])

# %%
log = drv.run_module(P, "paper1.fig09_sample_level")

# %%
drv.show(P, "fig09_sample_level")

# %%
drv.copy_to_paper(P, "fig09_sample_level.pdf")
